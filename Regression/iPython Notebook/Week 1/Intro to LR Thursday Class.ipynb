# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
X = 2*np.random.rand(100,1)
y = 3*X +np.random.rand(100,1)

data= pd.DataFrame({'X': X.flatten(), 'y': y.flatten()})

# %%
data.head()
# Out:
#           X         y
# 0  1.097627  3.970698
# 1  1.430379  4.561144
# 2  1.205527  4.351774
# 3  1.089766  4.231488
# 4  0.847310  2.790682

# %%
data.describe()
# Out:
#                 X           y
# count  100.000000  100.000000
# mean     0.945588    3.364845
# std      0.579508    1.742379
# min      0.009391    0.375002
# 25%      0.411606    1.694870
# 50%      0.934962    3.535182
# 75%      1.368967    4.676517
# max      1.976748    6.596964

# %%
sns.pairplot(data)

# %%
data.isnull().sum()
# Out:
# X    0
# y    0
# dtype: int64

# %% [markdown]
# ## Distribution

# %%
sns.pairplot(data)

# %%
from scipy import stats
z_scores = np.abs(stats.zscore())
